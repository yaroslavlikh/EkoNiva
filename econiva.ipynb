# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fields = pd.read_csv('fields.csv', decimal=',', sep=';', na_values='', encoding='cp1251')
works = pd.read_csv('works.csv', decimal=',', sep=';', encoding='cp1251')
value = pd.read_csv('value.csv', decimal=',', sep=';', na_values='', encoding='cp1251')

# %%
fields = fields.drop(columns = ['Unnamed: 18'])
fields = fields.drop_duplicates()
# works = works.drop(columns = ['main_tech', 'add_tech', 'mech'])

# %%
fields['id'] = fields['season'].map(str)+' '+fields['field'].map(str)
works['id'] = works['season'].map(str)+' '+works['field'].map(str)

# %%
print(list(works['main_tech']).count('Арендованная техника'))
print(len(works))
# Out:
# 10514
# 174683

# %%
works.isna().sum()
# Out:
# season                0
# field                 0
# work_type             0
# work_subtype          0
# start_date            0
# end_date           9004
# area                  0
# main_tech             0
# add_tech          48540
# mech                  0
# proc_depth       132562
# prod_purpose     140822
# prod_weight           0
# prod_dry_perc    161715
# prod_humid       151128
# prod_impur       151128
# yield_fact            0
# work_id               0
# dtype: int64

# %%
set(works['work_type'])
# Out:
# {'Внесение СЗР', 'Внесение удобрений', 'Обработка почвы', 'Сев', 'Уборка'}

# %%
merged_works = works.merge(fields, on='id', how='left')
merged_works
# Out:
#         season_x          field_x        work_type   work_subtype  start_date  \
# 0           2023  16.13.12.044.00  Обработка почвы    Боронование  29.04.2022
# 1           2023  16.13.12.017.00  Обработка почвы    Боронование  01.05.2022
# 2           2023  16.13.12.012.00  Обработка почвы    Боронование  02.05.2022
# 3           2023  16.13.12.012.00  Обработка почвы    Боронование  02.05.2022
# 4           2023  16.13.12.017.00  Обработка почвы    Боронование  02.05.2022
# ...          ...              ...              ...            ...         ...
# 174678      2024  54.17.12.029.00           Уборка  Подбор (корм)  27.10.2024
# 174679      2024  54.28.13.038.00           Уборка          Вывоз  27.10.2024
# 174680      2024  54.28.07.028.00  Обработка почвы    Культивация  28.10.2024
# 174681      2024  54.28.07.028.00  Обработка почвы    Культивация  28.10.2024
# 174682      2024  54.17.02.022.00           Уборка          Вывоз  28.10.2024
#
#           end_date  area_x                                          main_tech  \
# 0       30.04.2022   49,78  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 1       02.05.2022  154,76  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 2       03.05.2022   40,62  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 3       03.05.2022   86,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 4       03.05.2022   76,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# ...            ...     ...                                                ...
# 174678  27.10.2024   27,00  Комбайн кормоуборочный Ростсельмаш F2650, гос....
# 174679  27.10.2024    7,00  Трактор колесный Lovol 2604, зав.ном. M700060R...
# 174680  28.10.2024    3,14  Трактор колесный John Deere 8370R, гос.ном. 49...
# 174681  28.10.2024    6,00  Трактор колесный John Deere 9470R, гос.ном. 48...
# 174682  28.10.2024   73,93  Трактор колесный Птз К-744Р1, гос.ном. 2206НМ7...
#
#                                                  add_tech  \
# 0                                    Арендованная техника
# 1          Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 2                                    Арендованная техника
# 3          Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# 4          Борона зубовая Veles АГС-22-2У.М, зав.ном. 789
# ...                                                   ...
# 174678                                                NaN
# 174679                               Арендованная техника
# 174680  Культиватор стерневой Vaderstad TopDown 500, з...
# 174681  Культиватор стерневой Vaderstad TopDown 700, и...
# 174682                                                NaN
#
#                                    mech  ...  area_y          hybrid  \
# 0            Ахметсафин Айрат Рафикович  ...   49.78  Кинельская 100
# 1           Ямалетдинов Фарид Расыхович  ...  235.76         Девятка
# 2          Мухаметзянов Ринат Айратович  ...  126.62          Сузука
# 3                Шакиров Ринат Галиевич  ...  126.62          Сузука
# 4                Шакиров Ринат Галиевич  ...  235.76         Девятка
# ...                                 ...  ...     ...             ...
# 174678      Ульвачев Алексей Николаевич  ...  162.17        БН 06-18
# 174679          Лагунов Юрий Николаевич  ...  314.32         Скипетр
# 174680  Гопаненко Владимир Владимирович  ...  177.14             NaN
# 174681    Гамануха Дмитрий Владимирович  ...  177.14             NaN
# 174682      Строй Дмитрий Александрович  ...   73.93             NaN
#
#         reproduction  seed_origin             technology  yield_plan    p2o5  \
# 0                NaN          NaN                    NaN        1.24  217.43
# 1               РС-1     Покупные                    NaN        1.53  232.65
# 2                 F1     Покупные  классическая с плугом        1.70  247.50
# 3                 F1     Покупные  классическая с плугом        1.70  247.50
# 4               РС-1     Покупные                    NaN        1.53  232.65
# ...              ...          ...                    ...         ...     ...
# 174678           NaN     Покупные            минимальная        4.10    5.06
# 174679          РС-1     Покупные            минимальная        4.00    5.72
# 174680           NaN          NaN                    NaN         NaN    0.00
# 174681           NaN          NaN                    NaN         NaN    0.00
# 174682           NaN          NaN                    NaN        1.60    5.69
#
#            k2o   humus    ph
# 0       211.57    6.60  6.20
# 1       216.06    8.80  6.75
# 2       216.33    8.58  7.33
# 3       216.33    8.58  7.33
# 4       216.06    8.80  6.75
# ...        ...     ...   ...
# 174678  241.12  184.23  8.03
# 174679  216.26  347.81  6.27
# 174680    0.00    0.00  0.00
# 174681    0.00    0.00  0.00
# 174682  170.67  221.63  4.81
#
# [174683 rows x 37 columns]

# %%
df_arend = merged_works[merged_works['main_tech']=='Арендованная техника']

# %%
df_noarend = merged_works[merged_works['main_tech']!='Арендованная техника']

# %%
order = df_noarend["work_type"].value_counts().index.to_list()
sns.countplot(df_noarend['work_type'], order=order)
# Out:
# <Axes: xlabel='count', ylabel='work_type'>

# %%
order = df_arend["work_type"].value_counts().index.to_list()
sns.countplot(df_arend['work_type'], order=order)
# Out:
# <Axes: xlabel='count', ylabel='work_type'>

# %%
x = 'fertility_score'
y = 'area_y'
sns.jointplot(x = x, y = y, data=df_arend.replace({y: 0}, np.nan))

# %%
x = 'fertility_score'
y = 'area_y'
sns.jointplot(x = x, y = y, data=df_noarend.replace({y: 0}, np.nan))

# %%
s = 0
sc = 0
for i in df_arend.index:
    a = float('.'.join(df_arend['area_x'][i].split(',')))
    b = df_arend['area_y'][i]
    if str(a)!='nan' and str(b)!='nan':
        s+=a/b
        sc+=1
s/len(df_arend)
# Out:
# 0.5046650045223676

# %%
s = 0
sc = 0
for i in df_noarend.index:
    a = float('.'.join(df_noarend['area_x'][i].split(',')))
    b = df_noarend['area_y'][i]
    if str(a)!='nan' and str(b)!='nan':
        s+=a/b
        sc+=1
s/len(df_noarend)
# Out:
# 0.4602922117610272

# %%
df_arend[['proc_depth', 'yield_plan', 'p2o5', 'k2o', 'humus', 'ph', 'fertility_score']].mean()
# Out:
# proc_depth     14.904117
# yield_plan      4.683681
# p2o5           49.134854
# k2o           107.040611
# humus          67.726524
# ph              3.774538
# dtype: float64

# %%
df_noarend[['proc_depth', 'yield_plan', 'p2o5', 'k2o', 'humus', 'ph', 'fertility_score']].mean()
# Out:
# proc_depth          12.752275
# yield_plan           5.346293
# p2o5                59.878328
# k2o                116.752883
# humus               68.550976
# ph                   4.665615
# fertility_score      3.448185
# dtype: float64

# %%
merged_works.describe().T
# Out:
#                     count         mean           std      min      25%  \
# season_x         174683.0  2023.497455      0.499995  2023.00  2023.00
# proc_depth        42121.0    12.842853     36.716523     0.01     5.00
# prod_weight      174683.0  1593.576104  35510.437201     0.00     0.00
# prod_dry_perc     12968.0    41.971009     32.466702     0.00    32.00
# prod_humid        23555.0    15.457550     93.578670     0.00    12.00
# prod_impur        23555.0     4.352716      5.879178     0.00     2.00
# yield_fact       174683.0    32.732611   1146.791046     0.00     0.00
# fertility_score  160874.0     3.435073      0.834045     0.00     3.00
# season_y         167057.0  2023.497088      0.499993  2023.00  2023.00
# crop_yearold      28795.0     2.472408      1.590947     0.00     1.00
# area_y           167057.0   126.250945    134.346170     0.31    41.42
# yield_plan       157178.0     5.306898      7.189090     0.09     2.50
# p2o5             167057.0    59.218569     81.630457     0.00     5.39
# k2o              167057.0   116.156451     84.262825     0.00    60.50
# humus            167057.0    68.500346    135.948450     0.00     2.20
# ph               167057.0     4.610894      2.683242     0.00     2.42
#
#                      50%      75%         max
# season_x         2023.00  2024.00     2024.00
# proc_depth         10.00    20.00     7323.00
# prod_weight         0.00     0.00  6797437.50
# prod_dry_perc      36.00    41.00     1655.82
# prod_humid         14.00    16.50    14172.00
# prod_impur          3.00     5.00      230.00
# yield_fact          0.00     0.00   415745.40
# fertility_score     3.00     4.00        5.00
# season_y         2023.00  2024.00     2024.00
# crop_yearold        2.00     3.00       11.00
# area_y             90.30   162.91     1272.59
# yield_plan          4.00     5.60       60.00
# p2o5                6.65   106.43      746.90
# k2o               112.75   168.30      746.90
# humus               6.60    85.13     1313.87
# ph                  5.61     6.40       11.00
