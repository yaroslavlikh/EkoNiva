# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

'''
from google.colab import drive
drive.mount('/content/drive')
'''
# Out:
# "\nfrom google.colab import drive\ndrive.mount('/content/drive')\n"

# %%
fields = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/original_fields.csv',
                     encoding='cp1251', sep=';', na_values='', decimal=',')
fields = fields.drop(columns='Unnamed: 18')

fields.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fields = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/original_fields.csv',
#       2                      encoding='cp1251', sep=';', na_values='', decimal=',')
#       3 fields = fields.drop(columns='Unnamed: 18')
#       5 fields.head()
#
# ...

# %%
works = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/original_works.csv',
                     encoding='cp1251', sep=';', na_values='', decimal=',')

works.head()
# Out:
#    season            field        work_type work_subtype  start_date  \
# 0    2023  16.13.12.044.00  Обработка почвы  Боронование  29.04.2022
# 1    2023  16.13.12.017.00  Обработка почвы  Боронование  01.05.2022
# 2    2023  16.13.12.012.00  Обработка почвы  Боронование  02.05.2022
# 3    2023  16.13.12.012.00  Обработка почвы  Боронование  02.05.2022
# 4    2023  16.13.12.017.00  Обработка почвы  Боронование  02.05.2022
#
#      end_date    area                                          main_tech  \
# 0  30.04.2022   49,78  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 1  02.05.2022  154,76  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 2  03.05.2022   40,62  Трактор колесный Fendt 936 Vario, гос.ном. 050...
# 3  03.05.2022   86,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
# 4  03.05.2022   76,00  Трактор колесный Птз К-744Р4, гос.ном. 2251АА1...
#
#                                          add_tech  \
# 0                            Арендованная техника
# ...

# %% [markdown]
# имеем номинальную площадь поля, посчитаем для ключа(поле + год) сумму собранного на нем урожая, сумму обработанной площади
#
# 1) не для каждого поля из fields имеем записи в works, выберем те, которые встречаются там и тут
# 2)

# %%
works['total_grow'] = works.groupby()

# %%
'''df_for_regression = fields[['ph', 'humus', 'k2o', 'p2o5', 'fertility_score']].copy().dropna()
y = df_for_regression['fertility_score']
df_for_regression = df_for_regression.drop('fertility_score', axis=1)


from sklearn.metrics import mean_absolute_error as MAE
from sklearn.linear_model import LogisticRegression


model = LogisticRegression()

model.fit(df_for_regression, y)

print(MAE(y, model.predict(df_for_regression)))
'''
# Out:
# "df_for_regression = fields[['ph', 'humus', 'k2o', 'p2o5', 'fertility_score']].copy().dropna()\ny = df_for_regression['fertility_score']\ndf_for_regression = df_for_regression.drop('fertility_score', axis=1)\n\n\nfrom sklearn.metrics import mean_absolute_error as MAE\nfrom sklearn.linear_model import LogisticRegression\n\n\nmodel = LogisticRegression()\n\nmodel.fit(df_for_regression, y)\n\nprint(MAE(y, model.predict(df_for_regression)))\n"

# %%
'''df_for_regression.describe()
'''
# Out:
# 'df_for_regression.describe()\n'

# %%
'''from matplotlib import pyplot as plt

# Создание табличек из графиков
fig, axs = plt.subplots(4, 1, figsize=(8, 10))  # 2 строки, 1 столбец
y1 = df_for_regression['ph']

# Первый график
axs[0].scatter(df_for_regression['humus'], y1, color='blue', label='sin(x)')
axs[0].set_title('humus')
axs[0].legend()
axs[0].grid()


# Второй график
axs[1].scatter(df_for_regression['k2o'], y1, color='blue', label='sin(x)')
axs[1].set_title('k2o')
axs[1].legend()
axs[1].grid()

# Второй график
axs[2].scatter(df_for_regression['p2o5'], y1, color='blue', label='sin(x)')
axs[2].set_title('p2o5')
axs[2].legend()
axs[2].grid()


# Второй график
axs[3].scatter(y, y1, color='blue', label='sin(x)')
axs[3].set_title('fertility_score')
axs[3].legend()
axs[3].grid()

# Настройка интервалов между графиками
plt.tight_layout()

plt.show()'''
# Out:
# "from matplotlib import pyplot as plt\n\n# Создание табличек из графиков\nfig, axs = plt.subplots(4, 1, figsize=(8, 10))  # 2 строки, 1 столбец\ny1 = df_for_regression['ph']\n\n# Первый график\naxs[0].scatter(df_for_regression['humus'], y1, color='blue', label='sin(x)')\naxs[0].set_title('humus')\naxs[0].legend()\naxs[0].grid()\n\n\n# Второй график\naxs[1].scatter(df_for_regression['k2o'], y1, color='blue', label='sin(x)')\naxs[1].set_title('k2o')\naxs[1].legend()\naxs[1].grid()\n\n# Второй график\naxs[2].scatter(df_for_regression['p2o5'], y1, color='blue', label='sin(x)')\naxs[2].set_title('p2o5')\naxs[2].legend()\naxs[2].grid()\n\n\n# Второй график\naxs[3].scatter(y, y1, color='blue', label='sin(x)')\naxs[3].set_title('fertility_score')\naxs[3].legend()\naxs[3].grid()\n\n# Настройка интервалов между графиками\nplt.tight_layout()\n\nplt.show()"

# %%
'''import numpy as np
df_for_regression = fields[['ph', 'humus', 'k2o', 'p2o5', 'fertility_score']].copy()  #  .map(lambda x : {0:np.nan}.get(x, x)).dropna()
df_for_regression = df_for_regression.loc[~(df_for_regression['fertility_score'].isna())]


y = df_for_regression['fertility_score']
df_for_regression = df_for_regression.drop('fertility_score', axis=1)



from sklearn.metrics import mean_absolute_error as MAE
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso


model = RandomForestRegressor()

model.fit(df_for_regression, y)

print(MAE(y, model.predict(df_for_regression)))
model.coef_, model.intercept_
'''
# Out:
# "import numpy as np\ndf_for_regression = fields[['ph', 'humus', 'k2o', 'p2o5', 'fertility_score']].copy()  #  .map(lambda x : {0:np.nan}.get(x, x)).dropna()\ndf_for_regression = df_for_regression.loc[~(df_for_regression['fertility_score'].isna())]\n\n\ny = df_for_regression['fertility_score']\ndf_for_regression = df_for_regression.drop('fertility_score', axis=1)\n\n\n\nfrom sklearn.metrics import mean_absolute_error as MAE\nfrom sklearn.ensemble import RandomForestRegressor\nfrom sklearn.linear_model import Lasso\n\n\nmodel = RandomForestRegressor()\n\nmodel.fit(df_for_regression, y)\n\nprint(MAE(y, model.predict(df_for_regression)))\nmodel.coef_, model.intercept_\n"

# %%
'''pd.concat([y, df_for_regression]).corr()'''
# Out:
# 'pd.concat([y, df_for_regression]).corr()'

# %%
'''df_for_regression.describe()'''
# Out:
# 'df_for_regression.describe()'
